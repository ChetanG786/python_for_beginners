# %%
# pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
# html_response = requests.get('https://www.themoviedb.org/movie')

# %% [markdown]
# # Request page source from URL

# %%
url = 'https://www.themoviedb.org'

# %%
header = {'User-Agent':'Mozilla/5.0(Windows NT 6.3;Win64;x64)AppleWebKit/537.36(KHTML,like Gecko)Chrome/99.04844.51 Safari/537.36'}
url = 'https://www.themoviedb.org'

response = requests.get(url+'/movie', headers = header)

# %%
response
# Out:
# <Response [200]>

# %%
movie_data=response.text

# %%
soup = BeautifulSoup(movie_data,'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <title>Popular Movies — The Movie Database (TMDB)</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta charset="utf-8"/>
# <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="The Movie Database (TMDB) is a popular, user editable database for movies and TV shows." name="description"/>
# <meta content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png" name="msapplication-TileImage"/>
# <meta content="#032541" name="msapplication-TileColor"/>
# <meta content="#032541" name="theme-color"/>
# ...

# %%
all_movies_info = []
all_movies_name=soup.find_all('div',class_='card style_1')

for item in all_movies_name:
    movie_name = item.find('div',class_="content").h2.text
    movie_ratings= item.find('div',class_="user_score_chart")['data-percent']
    movie_link= item.find('div',class_="content").a['href']
    movie_link= "https://www.themoviedb.org"+movie_link
    ur12 = requests.get(movie_link,headers = header)
    mo_url= BeautifulSoup(ur12.text,'html')
    mo_url
    movie_release = mo_url.find('span',class_='release').text.strip().replace('(US)',' ').replace('(IN)',' ').replace('(CZ)',' ').replace('(FR)',' ').replace('(GB)',' ').replace('(KR)',' ').replace('(AU)',' ').replace('(DE)',' ')
    movie_genere = mo_url.find('span',class_='genres').text.strip().replace(',',',')
    movie_runtime = mo_url.find('span',class_='runtime').text.strip()
    director=mo_url.find('li',class_='profile').a.text


my_movies_dict= {
    "Movie Name":movie_name, 
    "Rating":movie_ratings,
    "Relese Date":movie_release,
    "Geners":movie_genere,
    "Runtime":movie_runtime,
    "Director":director,
    "Movies Link ":movie_link
    }
all_movies_info.append(my_movies_dict)
# movies_list.append(my_movies_dict)

print(all_movies_info)
# Out:
# [{'Movie Name': 'Venom: Let There Be Carnage', 'Rating': '70', 'Relese Date': '10/14/2021 (SG)', 'Geners': 'Science Fiction,\xa0Action,\xa0Adventure', 'Runtime': '1h 37m', 'Director': 'Kelly Marcel', 'Movies Link ': 'https://www.themoviedb.org/movie/580489'}]

# %%
url_lst=[]
url="https://www.themoviedb.org/movie?page="
for i in range(1,151):
    nw_link=url+str(i)
    url_lst.append(nw_link)
url_lst
# Out:
# ['https://www.themoviedb.org/movie?page=1',
#  'https://www.themoviedb.org/movie?page=2',
#  'https://www.themoviedb.org/movie?page=3',
#  'https://www.themoviedb.org/movie?page=4',
#  'https://www.themoviedb.org/movie?page=5',
#  'https://www.themoviedb.org/movie?page=6',
#  'https://www.themoviedb.org/movie?page=7',
#  'https://www.themoviedb.org/movie?page=8',
#  'https://www.themoviedb.org/movie?page=9',
#  'https://www.themoviedb.org/movie?page=10',
#  'https://www.themoviedb.org/movie?page=11',
#  'https://www.themoviedb.org/movie?page=12',
#  'https://www.themoviedb.org/movie?page=13',
#  'https://www.themoviedb.org/movie?page=14',
#  'https://www.themoviedb.org/movie?page=15',
#  'https://www.themoviedb.org/movie?page=16',
#  'https://www.themoviedb.org/movie?page=17',
#  'https://www.themoviedb.org/movie?page=18',
#  'https://www.themoviedb.org/movie?page=19',
#  'https://www.themoviedb.org/movie?page=20',
#  'https://www.themoviedb.org/movie?page=21',
# ...

# %%
for i in url_lst:
    print(i)
# Out:
# https://www.themoviedb.org/movie?page=1
# https://www.themoviedb.org/movie?page=2
# https://www.themoviedb.org/movie?page=3
# https://www.themoviedb.org/movie?page=4
# https://www.themoviedb.org/movie?page=5
# https://www.themoviedb.org/movie?page=6
# https://www.themoviedb.org/movie?page=7
# https://www.themoviedb.org/movie?page=8
# https://www.themoviedb.org/movie?page=9
# https://www.themoviedb.org/movie?page=10
# https://www.themoviedb.org/movie?page=11
# https://www.themoviedb.org/movie?page=12
# https://www.themoviedb.org/movie?page=13
# https://www.themoviedb.org/movie?page=14
# https://www.themoviedb.org/movie?page=15
# https://www.themoviedb.org/movie?page=16
# https://www.themoviedb.org/movie?page=17
# https://www.themoviedb.org/movie?page=18
# https://www.themoviedb.org/movie?page=19
# https://www.themoviedb.org/movie?page=20
# https://www.themoviedb.org/movie?page=21
# https://www.themoviedb.org/movie?page=22
# https://www.themoviedb.org/movie?page=23
# ...

# %%
mov1 =[]
rat = []
link1 = [] 
rele = []
temp = []
def scraped_data ():
    

    for i in url_lst :
        header = {'User-Agent':'Mozila/5.0(Windows NT 6.3;Win64;x64)AppleWebkit/537.36(KHTML,like Gecko)Chrome/99.0.4844.51 Safari/537.36'}
        html_response = requests.get(i,headers=header)
        content = html_response.text
        soup = BeautifulSoup(content,'html')
        movies_all = soup.find_all('div' , class_='card style_1')
        #print(i)
        for item in movies_all:
            movies_name=item.find('div',class_='content') 
            movies_name=movies_name.find("h2").text
            
            movie_rating=item.find('div',class_='user_score_chart')['data-percent']
            
            Movie_link=item.find('a',class_='image')['href']
            url='https://www.themoviedb.org/'
            movie_link=url+Movie_link
            
            movie_relse_date = item.find('div',class_='content').p.text
            
    


            my_movies_dict= {
            "Movie Name":movies_name, 
            "Rating":movie_rating,
            "Movies Link ":movie_link,
            'Relse':movie_relse_date,
     
            }
            print(my_movies_dict)
            
            temp.append(my_movies_dict)  
scraped_data()
# Out:
# {'Movie Name': 'The Batman', 'Rating': '78.0', 'Movies Link ': 'https://www.themoviedb.org//movie/414906', 'Relse': 'Mar 01, 2022'}
# {'Movie Name': 'Uncharted', 'Rating': '72.0', 'Movies Link ': 'https://www.themoviedb.org//movie/335787', 'Relse': 'Feb 10, 2022'}
# {'Movie Name': 'Spider-Man: No Way Home', 'Rating': '81.0', 'Movies Link ': 'https://www.themoviedb.org//movie/634649', 'Relse': 'Dec 15, 2021'}
# {'Movie Name': 'The Outfit', 'Rating': '70', 'Movies Link ': 'https://www.themoviedb.org//movie/799876', 'Relse': 'Feb 25, 2022'}
# {'Movie Name': 'Turning Red', 'Rating': '75.0', 'Movies Link ': 'https://www.themoviedb.org//movie/508947', 'Relse': 'Mar 10, 2022'}
# {'Movie Name': 'Sonic the Hedgehog 2', 'Rating': '76.0', 'Movies Link ': 'https://www.themoviedb.org//movie/675353', 'Relse': 'Mar 30, 2022'}
# {'Movie Name': 'Yaksha: Ruthless Operations', 'Rating': '62.0', 'Movies Link ': 'https://www.themoviedb.org//movie/606402', 'Relse': 'Apr 08, 2022'}
# ...

# %%
import pandas as pd
df = pd.DataFrame(temp)
df
# Out:
#                       Movie Name Rating  \
# 0                     The Batman   78.0
# 1                      Uncharted   72.0
# 2        Spider-Man: No Way Home   81.0
# 3                     The Outfit     70
# 4                    Turning Red   75.0
# ...                          ...    ...
# 2995       Tremors 5: Bloodlines   55.0
# 2996  E.T. the Extra-Terrestrial   75.0
# 2997                  Bingo Hell   48.0
# 2998         Tomorrow Never Dies   63.0
# 2999          Lady and the Tramp   73.0
#
#                                   Movies Link          Relse
# 0     https://www.themoviedb.org//movie/414906  Mar 01, 2022
# 1     https://www.themoviedb.org//movie/335787  Feb 10, 2022
# 2     https://www.themoviedb.org//movie/634649  Dec 15, 2021
# 3     https://www.themoviedb.org//movie/799876  Feb 25, 2022
# 4     https://www.themoviedb.org//movie/508947  Mar 10, 2022
# ...                                        ...           ...
# ...

# %%
movieinfo=[]
def get_all_movies_data():
    for link in url_lst:
        response = requests.get(link,headers={'User-Agent':'Mozila/5.0(Windows NT 6.3;Win64;x64)AppleWebkit/537.36(KHTML,like Gecko)Chrome/99.0.4844.51 Safari/537.36'})
        html_text = response.text
        movie_soup = BeautifulSoup(html_text,'html')
        all_movie_pages = movie_soup.find_all('div',class_='card style_1')
        for item in all_movie_pages:
            movie_name = item.find('div',class_="content").h2.text
            movie_ratings= item.find('div',class_="user_score_chart")['data-percent']
            movie_link= item.find('div',class_="content").a['href']
            movie_link= "https://www.themoviedb.org"+movie_link
            movie_specificurl = requests.get(movie_link,headers ={'User-Agent': 'Mozilla/5.0 '} )
            movie_specificurl2= BeautifulSoup(movie_specificurl.text,'html')
            movie_specificurl2
            movie_release = movie_specificurl2.find('span',class_='release').text.strip()
            movie_genere = movie_specificurl2.find('span',class_='genres').text.strip().replace(',',',')
            runtime = movie_specificurl2.find('span',class_='runtime')
            if runtime is not None:
                runtime=(runtime.text.strip())
            director=movie_specificurl2.find('li',class_='profile')
            if director is not None:
                director=(director.p.text)
            my_movies = {
                'Name':movie_name,
                'Ratings':movie_ratings,
                'Genere':movie_genere,
                'Release date':movie_release,
                'Runtime' :runtime,
                'Director' :director,
                'Url':movie_link
            }

            movieinfo.append(my_movies)
get_all_movies_data()

# %%
movieinfo
# Out:
# [{'Name': 'The Batman',
#   'Ratings': '78.0',
#   'Genere': 'Crime,\xa0Mystery,\xa0Thriller',
#   'Release date': '03/03/2022 (SG)',
#   'Runtime': '2h 56m',
#   'Director': 'Matt Reeves',
#   'Url': 'https://www.themoviedb.org/movie/414906'},
#  {'Name': 'Uncharted',
#   'Ratings': '72.0',
#   'Genere': 'Action,\xa0Adventure,\xa0Family',
#   'Release date': '02/17/2022 (SG)',
#   'Runtime': '1h 56m',
#   'Director': 'Ruben Fleischer',
#   'Url': 'https://www.themoviedb.org/movie/335787'},
#  {'Name': 'Spider-Man: No Way Home',
#   'Ratings': '81.0',
#   'Genere': 'Action,\xa0Adventure,\xa0Science Fiction',
#   'Release date': '12/16/2021 (SG)',
#   'Runtime': '2h 28m',
#   'Director': 'Stan Lee',
#   'Url': 'https://www.themoviedb.org/movie/634649'},
#  {'Name': 'The Outfit',
#   'Ratings': '70',
#   'Genere': 'Drama,\xa0Thriller,\xa0Crime',
#   'Release date': '03/18/2022 (US)',
#   'Runtime': '1h 45m',
#   'Director': 'Graham Moore',
# ...

# %%
movie_product = pd.DataFrame(movieinfo)

# %%
movie_product
# Out:
#                             Name Ratings  \
# 0                     The Batman    78.0
# 1                      Uncharted    72.0
# 2        Spider-Man: No Way Home    81.0
# 3                     The Outfit      70
# 4                    Turning Red    75.0
# ...                          ...     ...
# 2995       Tremors 5: Bloodlines    55.0
# 2996  E.T. the Extra-Terrestrial    75.0
# 2997                  Bingo Hell    48.0
# 2998         Tomorrow Never Dies    63.0
# 2999          Lady and the Tramp    73.0
#
#                                                  Genere     Release date  \
# 0                              Crime, Mystery, Thriller  03/03/2022 (SG)
# 1                             Action, Adventure, Family  02/17/2022 (SG)
# 2                    Action, Adventure, Science Fiction  12/16/2021 (SG)
# 3                                Drama, Thriller, Crime  03/18/2022 (US)
# 4                    Animation, Family, Comedy, Fantasy  03/10/2022 (CZ)
# ...

# %%
movie_product.to_csv('Webscraping Data.csv')

# %%
data= pd.read_csv('Webscraping Data.csv')

# %%
data
# Out:
#       Unnamed: 0                        Name  Ratings  \
# 0              0                  The Batman     78.0
# 1              1                   Uncharted     72.0
# 2              2     Spider-Man: No Way Home     81.0
# 3              3                  The Outfit     70.0
# 4              4                 Turning Red     75.0
# ...          ...                         ...      ...
# 2995        2995       Tremors 5: Bloodlines     55.0
# 2996        2996  E.T. the Extra-Terrestrial     75.0
# 2997        2997                  Bingo Hell     48.0
# 2998        2998         Tomorrow Never Dies     63.0
# 2999        2999          Lady and the Tramp     73.0
#
#                                                  Genere     Release date  \
# 0                              Crime, Mystery, Thriller  03/03/2022 (SG)
# 1                             Action, Adventure, Family  02/17/2022 (SG)
# 2                    Action, Adventure, Science Fiction  12/16/2021 (SG)
# ...

# %%
data_movie = data.copy()

# %%
data_movie
# Out:
#       Unnamed: 0                        Name  Ratings  \
# 0              0                  The Batman     78.0
# 1              1                   Uncharted     72.0
# 2              2     Spider-Man: No Way Home     81.0
# 3              3                  The Outfit     70.0
# 4              4                 Turning Red     75.0
# ...          ...                         ...      ...
# 2995        2995       Tremors 5: Bloodlines     55.0
# 2996        2996  E.T. the Extra-Terrestrial     75.0
# 2997        2997                  Bingo Hell     48.0
# 2998        2998         Tomorrow Never Dies     63.0
# 2999        2999          Lady and the Tramp     73.0
#
#                                                  Genere     Release date  \
# 0                              Crime, Mystery, Thriller  03/03/2022 (SG)
# 1                             Action, Adventure, Family  02/17/2022 (SG)
# 2                    Action, Adventure, Science Fiction  12/16/2021 (SG)
# ...

# %% [markdown]
# ## Starting with Data Cleansing

# %%
data_movie.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Ratings', 'Genere', 'Release date', 'Runtime',
#        'Director', 'Url'],
#       dtype='object')

# %%
data_movie.drop(['Unnamed: 0'],inplace=True,axis = 1)

# %%
data_movie.columns
# Out:
# Index(['Name', 'Ratings', 'Genere', 'Release date', 'Runtime', 'Director',
#        'Url'],
#       dtype='object')

# %%
data_movie
# Out:
#                             Name  Ratings  \
# 0                     The Batman     78.0
# 1                      Uncharted     72.0
# 2        Spider-Man: No Way Home     81.0
# 3                     The Outfit     70.0
# 4                    Turning Red     75.0
# ...                          ...      ...
# 2995       Tremors 5: Bloodlines     55.0
# 2996  E.T. the Extra-Terrestrial     75.0
# 2997                  Bingo Hell     48.0
# 2998         Tomorrow Never Dies     63.0
# 2999          Lady and the Tramp     73.0
#
#                                                  Genere     Release date  \
# 0                              Crime, Mystery, Thriller  03/03/2022 (SG)
# 1                             Action, Adventure, Family  02/17/2022 (SG)
# 2                    Action, Adventure, Science Fiction  12/16/2021 (SG)
# 3                                Drama, Thriller, Crime  03/18/2022 (US)
# 4                    Animation, Family, Comedy, Fantasy  03/10/2022 (CZ)
# ...

# %%
data_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          3000 non-null   object
#  1   Ratings       3000 non-null   float64
#  2   Genere        2987 non-null   object
#  3   Release date  3000 non-null   object
#  4   Runtime       2953 non-null   object
#  5   Director      2973 non-null   object
#  6   Url           3000 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 164.2+ KB

# %%
data_movie.describe()
# Out:
#          Ratings
# count  3000.0000
# mean     65.4120
# std      11.9366
# min       0.0000
# 25%      61.0000
# 50%      67.0000
# 75%      73.0000
# max      98.0000

# %%
data_movie.isnull().sum()
# Out:
# Name             0
# Ratings          0
# Genere          13
# Release date     0
# Runtime         47
# Director        27
# Url              0
# dtype: int64

# %%
data_movie['Genere'].fillna('0',inplace=True)

# %%
data_movie['Runtime'].fillna('0',inplace=True)

# %%
data_movie['Director'].fillna('0',inplace=True)

# %%
data_movie.isnull().sum()
# Out:
# Name            0
# Ratings         0
# Genere          0
# Release date    0
# Runtime         0
# Director        0
# Url             0
# dtype: int64

# %%
data_movie.columns
# Out:
# Index(['Name', 'Ratings', 'Genere', 'Release date', 'Runtime', 'Director',
#        'Url'],
#       dtype='object')

# %%
data_movie['Name'].unique()
# Out:
# array(['The Batman', 'Uncharted', 'Spider-Man: No Way Home', ...,
#        'E.T. the Extra-Terrestrial', 'Bingo Hell', 'Tomorrow Never Dies'],
#       dtype=object)

# %%
data_movie['Name'].nunique()
# Out:
# 2944

# %%
data_movie['Name'].count()
# Out:
# 3000

# %%
data_movie['Release date'].min()
# Out:
# '01/01/1981 (BR)'

# %%
data_movie['Release date'].max()
# Out:
# '12/31/2006 (US)'

# %%
df2 = data_movie.groupby(['Name','Ratings']).max()

# %% [markdown]
# ### Top 5 Movies superior Rating

# %%
df2.sort_values(by='Name').head(5)
# Out:
#                                                                Genere  \
# Name                       Ratings
# #Alive                     73.0              Action, Horror, Thriller
# (500) Days of Summer       73.0                Comedy, Drama, Romance
# 10 Things I Hate About You 76.0                Comedy, Romance, Drama
# 10,000 BC                  54.0     Adventure, Action, Drama, Fantasy
# 10.0 Earthquake            49.0              Drama, Adventure, Action
#
#                                        Release date Runtime         Director  \
# Name                       Ratings
# #Alive                     73.0     06/24/2020 (KR)  1h 38m           Cho Il
# (500) Days of Summer       73.0     10/08/2009 (SG)  1h 35m        Marc Webb
# 10 Things I Hate About You 76.0     03/31/1999 (US)  1h 37m       Gil Junger
# 10,000 BC                  54.0     03/05/2008 (US)  1h 49m  Roland Emmerich
# 10.0 Earthquake            49.0     10/15/2014 (US)  1h 28m     David Gidali
#
# ...

# %% [markdown]
# ## Top 5 Inferior Movie Rating

# %%
df2.sort_values(by = 'Name').tail(5)
# Out:
#                                           Genere     Release date Runtime  \
# Name           Ratings
# ¡Qué Despadre! 56.0      Comedy, Family, Romance  02/09/2022 (MX)  1h 39m
# ¿Y cómo es él? 63.0                       Comedy  04/07/2022 (MX)  1h 35m
# ×××HOLiC       0.0                         Drama  04/29/2022 (JP)       0
# 映画 賭ケグルイ       77.0     Drama, Mystery, Thriller  05/03/2019 (JP)  1h 59m
# 聊斋艳谭之婴宁        0.0                Drama, Fantasy  12/01/1997 (HK)       0
#
#                                   Director  \
# Name           Ratings
# ¡Qué Despadre! 56.0     Pedro Pablo Ibarra
# ¿Y cómo es él? 63.0         Ariel Winograd
# ×××HOLiC       0.0           Mika Ninagawa
# 映画 賭ケグルイ       77.0       Tsutomu Hanabusa
# 聊斋艳谭之婴宁        0.0                       0
#
#                                                             Url
# Name           Ratings
# ¡Qué Despadre! 56.0     https://www.themoviedb.org/movie/937337
# ...

# %%
df3=data_movie.groupby(['Director'])['Ratings'].max()

# %% [markdown]
# ## Director with High Rating Movies

# %%
df3.sort_values(ascending=True).head(5)
# Out:
# Director
# Goro Taniguchi      0.0
# Ahmed Khan          0.0
# Shinji Imaoka       0.0
# Michael D. Olmos    0.0
# Ian Homsy           0.0
# Name: Ratings, dtype: float64

# %% [markdown]
# ## Director with Low Rating Movies

# %%
df3.sort_values(ascending=True).tail(5)
# Out:
# Director
# Daniel Scheinert           88.0
# Haruo Sotozaki             88.0
# Carla Simón                90.0
# Carlos Pérez Osorio        90.0
# Christopher Winterbauer    98.0
# Name: Ratings, dtype: float64

# %%
df4= data_movie.groupby(['Release date','Ratings']).max()

# %%
df4
# Out:
#                                                                       Name  \
# Release date    Ratings
# 01/01/1981 (BR) 43.0                                                 Porno
# 01/01/1989 (LV) 62.0                                                   XXX
# 01/01/1991 (MX) 50.0                                 Cuando te veo palpito
# 01/01/1993 (MX) 40.0                                 El despertar del sexo
# 01/01/1999 (CL) 59.0                                           Sex Stories
# ...                                                                    ...
# 12/30/2021 (SG) 67.0                                        House of Gucci
#                 70.0                                        The King's Man
#                 76.0                           Hilda and the Mountain King
# 12/31/1993 (JP) 70.0     Looking Back at it All: The Dragon Ball Z Year...
# 12/31/2006 (US) 62.0                                    The Barbie Diaries
#
# ...

# %% [markdown]
# ## Top 5 Released date Low Ratings Movies

# %%
df4.sort_values(by='Release date').head(5)
# Out:
#                                           Name Genere Runtime  \
# Release date    Ratings
# 01/01/1981 (BR) 43.0                     Porno  Drama  1h 23m
# 01/01/1989 (LV) 62.0                       XXX      0       0
# 01/01/1991 (MX) 50.0     Cuando te veo palpito      0       0
# 01/01/1993 (MX) 40.0     El despertar del sexo      0       0
# 01/01/1999 (CL) 59.0               Sex Stories  Drama       0
#
#                                  Director  \
# Release date    Ratings
# 01/01/1981 (BR) 43.0      Luiz Castellini
# 01/01/1989 (LV) 62.0     Askolds Saulītis
# 01/01/1991 (MX) 50.0                    0
# 01/01/1993 (MX) 40.0                    0
# 01/01/1999 (CL) 59.0     Daniel Benavides
#
#                                                              Url
# Release date    Ratings
# 01/01/1981 (BR) 43.0     https://www.themoviedb.org/movie/197158
# 01/01/1989 (LV) 62.0     https://www.themoviedb.org/movie/806675
# ...

# %% [markdown]
# ## Top 5 Released date High Ratings Movies

# %%
df4.sort_values(by='Release date').tail(5)
# Out:
#                                                                       Name  \
# Release date    Ratings
# 12/30/2021 (SG) 67.0                                        House of Gucci
#                 70.0                                        The King's Man
#                 76.0                           Hilda and the Mountain King
# 12/31/1993 (JP) 70.0     Looking Back at it All: The Dragon Ball Z Year...
# 12/31/2006 (US) 62.0                                    The Barbie Diaries
#
#                                                                   Genere  \
# Release date    Ratings
# 12/30/2021 (SG) 67.0                              Drama, Crime, Thriller
#                 70.0           Action, Adventure, Thriller, War, Mystery
#                 76.0     Animation, Adventure, Fantasy, Family, TV Movie
# 12/31/1993 (JP) 70.0                           Action, Animation, Comedy
# 12/31/2006 (US) 62.0                                   Family, Animation
#
# ...

# %% [markdown]
# ## Average Movies

# %%
data_movie.groupby(['Release date'])[['Name','Genere','Runtime','Ratings','Director']].max()
# Out:
#                                                               Name  \
# Release date
# 01/01/1981 (BR)                                              Porno
# 01/01/1989 (LV)                                                XXX
# 01/01/1991 (MX)                              Cuando te veo palpito
# 01/01/1993 (MX)                              El despertar del sexo
# 01/01/1999 (CL)                                        Sex Stories
# ...                                                            ...
# 12/30/2018 (NL)                                  After Porn Ends 3
# 12/30/2021 (BR)                        Monica and Friends: Lessons
# 12/30/2021 (SG)                                     The King's Man
# 12/31/1993 (JP)  Looking Back at it All: The Dragon Ball Z Year...
# 12/31/2006 (US)                                 The Barbie Diaries
#
#                                     Genere Runtime  Ratings           Director
# Release date
# ...

# %% [markdown]
# ## Popular Movies

# %%
data_movie.groupby(['Name'])[['Release date','Genere','Runtime','Ratings','Director']].max()
# Out:
#                                Release date  \
# Name
# #Alive                      06/24/2020 (KR)
# (500) Days of Summer        10/08/2009 (SG)
# 10 Things I Hate About You  03/31/1999 (US)
# 10,000 BC                   03/05/2008 (US)
# 10.0 Earthquake             10/15/2014 (US)
# ...                                     ...
# ¡Qué Despadre!              02/09/2022 (MX)
# ¿Y cómo es él?              04/07/2022 (MX)
# ×××HOLiC                    04/29/2022 (JP)
# 映画 賭ケグルイ                    05/03/2019 (JP)
# 聊斋艳谭之婴宁                     12/01/1997 (HK)
#
#                                                        Genere Runtime  \
# Name
# #Alive                               Action, Horror, Thriller  1h 38m
# (500) Days of Summer                   Comedy, Drama, Romance  1h 35m
# 10 Things I Hate About You             Comedy, Romance, Drama  1h 37m
# 10,000 BC                   Adventure, Action, Drama, Fantasy  1h 49m
# ...
